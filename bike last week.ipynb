# %% [markdown]
# <a href="https://colab.research.google.com/github/Anitagg1/Phyton-Workshop/blob/main/bike%20last%20week.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
last_week = pd.read_csv('last_week.csv')

# %%
last_week
# Out:
#      Unnamed: 0         day  hour member_type  count
# 0             0  2021-01-25     0      casual      4
# 1             1  2021-01-25     0      member      4
# 2             2  2021-01-25     1      casual      2
# 3             3  2021-01-25     1      member      4
# 4             4  2021-01-25     2      casual      3
# ..          ...         ...   ...         ...    ...
# 329         329  2021-01-31    21      member     15
# 330         330  2021-01-31    22      casual      9
# 331         331  2021-01-31    22      member     12
# 332         332  2021-01-31    23      casual      3
# 333         333  2021-01-31    23      member      7
#
# [334 rows x 5 columns]

# %%
sns.catplot(x="day", y="count", hue="member_type", kind="swarm", data=last_week)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 8.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 10.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
