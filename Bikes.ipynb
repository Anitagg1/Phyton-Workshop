# %% [markdown]
# <a href="https://colab.research.google.com/github/Anitagg1/Phyton-Workshop/blob/main/Bikes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
drive.mount("/content/drive", force_remount=False)

# %%
bike_day = pd.read_csv('/content/drive/My Drive/day.csv')

# %%
import pandas as pd

bike_day = pd.read_csv('day.csv')

# %%
bike_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   daytime     731 non-null    object
#  2   season      731 non-null    int64
#  3   year        731 non-null    int64
#  4   month       731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
bike_day.rename(columns={'dteday' : 'daytime', 'yr' : 'year', 'mnth' : 'month'}, inplace=True)

# %%
bike_day.isnull().sum()
# Out:
# instant       0
# daytime       0
# season        0
# year          0
# month         0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
bike_day["daytime"]= pd.to_datetime(bike_day["daytime"])

# %%
for col in ['season', 'holiday', 'weekday', 'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'casual', 'registered', 'cnt']:
   bike_day[col] = bike_day[col].astype('category')

# %%
bike_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   daytime     731 non-null    datetime64[ns]
#  2   season      731 non-null    category
#  3   year        731 non-null    object
#  4   month       731 non-null    int64
#  5   holiday     731 non-null    category
#  6   weekday     731 non-null    category
#  7   workingday  731 non-null    category
#  8   weathersit  731 non-null    category
#  9   temp        731 non-null    category
#  10  atemp       731 non-null    category
#  11  hum         731 non-null    category
#  12  windspeed   731 non-null    category
#  13  casual      731 non-null    category
#  14  registered  731 non-null    category
#  15  cnt         731 non-null    category
# dtypes: category(12), datetime64[ns](1), int64(2), object(1)
# memory usage: 211.9+ KB

# %%
bike_day['weekday'].value_counts()

# %%
bike_day.loc[bike_day['year'] == 1, 'year'] = '2012'
bike_day.loc[bike_day['year'] == 0, 'year'] = '2011'

# %%
bike_day.loc[bike_day['season'] == 1, 'season'] = 'Spring'
bike_day.loc[bike_day['season'] == 2, 'season'] = 'Summer'
bike_day.loc[bike_day['season'] == 3, 'season'] = 'Fall'
bike_day.loc[bike_day['season'] == 4, 'season'] = 'Winter'

# %%
bike_day.loc[bike_day['weekday'] == 1, 'weekday'] = 'Monday'
bike_day.loc[bike_day['weekday'] == 2, 'weekday'] = 'Tuesday'
bike_day.loc[bike_day['weekday'] == 3, 'weekday'] = 'Wednesday'
bike_day.loc[bike_day['weekday'] == 4, 'weekday'] = 'Thursday'
bike_day.loc[bike_day['weekday'] == 5, 'weekday'] = 'Friday'
bike_day.loc[bike_day['weekday'] == 6, 'weekday'] = 'Saturday'
bike_day.loc[bike_day['weekday'] == 0, 'weekday'] = 'Sunday'

# %%
bike_day.loc[bike_day['season'] == 1, 'season'] = 'Winter'
bike_day.loc[bike_day['season'] == 2, 'season'] = 'Spring'
bike_day.loc[bike_day['season'] == 3, 'season'] = 'Summer'
bike_day.loc[bike_day['season'] == 4, 'season'] = 'Fall'

# %%
bike_day.loc[bike_day['holiday'] == 0, 'holiday'] = 'no'
bike_day.loc[bike_day['holiday'] == 1, 'holiday'] = 'yes'

# %%
bike_day.loc[bike_day['weathersit'] == 1, 'weathersit'] = 'clear'
bike_day.loc[bike_day['weathersit'] == 2, 'weathersit'] = 'cloudy'
bike_day.loc[bike_day['weathersit'] == 3, 'weathersit'] = 'LRain'
bike_day.loc[bike_day['weathersit'] == 4, 'weathersit'] = 'Snow'

# %%
bike_day

# %%
# causal customers rent the most on weekends
sns.catplot(x="weekday", y="casual", hue="year", kind="swarm", data=bike_day)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 16.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 13.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 14.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 11.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 6.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# registered customers rent throughout the working week more than during the weekends, although the difference is not big. 
sns.catplot(x="weekday", y="registered", hue="year", kind="swarm", data=bike_day)

# %%
sns.catplot(x="month", y="registered", hue="year", kind="swarm", data=bike_day)

# %%
import matplotlib.pyplot as plt

# %%
bike_day['daytime'].plot(linewidth=0.5);

# %%
cols_plot = ['casual', 'registered']
axes = bike_day[cols_plot].plot(marker='.', alpha=0.5, linestyle='None', figsize=(11, 9), subplots=True)
for ax in axes:
    ax.set_ylabel('Total reservations')

# %%
ax = bike_day.loc['daytime'].plot()

# %%
# Nobody rents when the weather is strong rain and snow
sns.catplot(x="weathersit", y="registered", hue="year", kind="swarm", data=bike_day)

# %%
bike_day['weathersit'].value_counts(ascending=False)
# Out:
# clear     463
# cloudy    247
# LRain      21
# Name: weathersit, dtype: int64

# %%
bike_day['cnt'].value_counts(ascending=False)

# %%
bike_day.groupby('weathersit')['year'].value_counts().sort_index(ascending=True)
# Out:
# weathersit  year
# LRain       2011     15
#             2012      6
# clear       2011    226
#             2012    237
# cloudy      2011    124
#             2012    123
# Name: year, dtype: int64

# %%
bike_day.groupby('holiday')['weathersit'].value_counts().sort_index(ascending=True)
# Out:
# holiday  weathersit
# no       LRain          21
#          clear         448
#          cloudy        241
# yes      clear          15
#          cloudy          6
# Name: weathersit, dtype: int64

# %%
#Registered customers use the service mostly during workdays but very much (in comparison with casual customers) as well during weekend and holidays.

sns.catplot(x="workingday", y="registered", hue="year", kind="swarm", data=bike_day)

# %%
sns.catplot(x="workingday", y="casual", hue="year", kind="swarm", data=bike_day)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 13.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# only day bike info for 2011
bikes_2011 = bike_day[bike_day.year.isin(['2011'])]

# %%
sns.catplot(x="season", y='cnt', hue="year", kind="swarm", data=bike_day)

# %%
bikes_2011

# %%
sns.catplot(x="weathersit", y="registered", hue="year", kind="swarm", data=bikes_2011)

# %%
# only day bike info for 2012
bikes_2012 = bike_day[bike_day.year.isin(['2012'])]

# %%
sns.catplot(x="weathersit", y="registered", hue="year", kind="swarm", data=bikes_2012)

# %%
numeric_bike = pandas.read_csv('day.csv')

# %%
numeric_bike.rename(columns={'dteday' : 'daytime', 'yr' : 'year', 'mnth' : 'month'}, inplace=True)

# %%
numeric_bike12 = numeric_bike[numeric_bike.year.isin(['1'])]

# %%
import seaborn as sns

sns.set(rc={'figure.figsize':(11,8)})

sns.set_context("paper", font_scale=1, rc={"lines.linewidth": 2.5})
#sns.set(style="ticks", context="talk")
#plt.style.use("dark_background")
sns.set_style("dark")

#fig, ax = plt.subplots()
ax = sns.pointplot(data = numeric_bike[['daytime','registered','year']], x = 'daytime', y = 'registered',
              scale = 0.2, hue = 'year');

plt.setp(ax.get_legend().get_texts(), fontsize='15') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='16') # for legend title

ax.set(title = 'Season wise hourly distribution of bike rentals',ylabel= 'mean(total_count)');

# %%
import seaborn as sns

sns.set(rc={'figure.figsize':(11,8)})

sns.set_context("paper", font_scale=1, rc={"lines.linewidth": 2.5})
#sns.set(style="ticks", context="talk")
#plt.style.use("dark_background")
sns.set_style("dark")

#fig, ax = plt.subplots()
ax = sns.pointplot(data = numeric_bike12[['month','registered','season']], x = 'month', y = 'registered',
              scale = 0.2, hue = 'season');

plt.setp(ax.get_legend().get_texts(), fontsize='15') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='16') # for legend title

ax.set(title = 'Season wise daily distribution of bike rentals',ylabel= 'total_count');

# %%
numeric_bike12.loc[numeric_bike12['season'] == 1, 'season'] = 'Spring'
numeric_bike12.loc[numeric_bike12['season'] == 2, 'season'] = 'Summer'
numeric_bike12.loc[numeric_bike12['season'] == 3, 'season'] = 'Fall'
numeric_bike12.loc[numeric_bike12['season'] == 4, 'season'] = 'Winter'
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
numeric_bike12.loc[numeric_bike12['weathersit'] == 1, 'weathersit'] = 'clear'
numeric_bike12.loc[numeric_bike12['weathersit'] == 2, 'weathersit'] = 'cloudy'
numeric_bike12.loc[numeric_bike12['weathersit'] == 3, 'weathersit'] = 'LRain'
numeric_bike12.loc[numeric_bike12['weathersit'] == 4, 'weathersit'] = 'Snow'
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
import seaborn as sns

sns.set(rc={'figure.figsize':(11,8)})

sns.set_context("paper", font_scale=1, rc={"lines.linewidth": 2.5})
#sns.set(style="ticks", context="talk")
#plt.style.use("dark_background")
sns.set_style("dark")

#fig, ax = plt.subplots()
ax = sns.pointplot(data = numeric_bike12[['daytime','cnt','season']], x = 'daytime', y = 'cnt',
              scale = 0.2, hue = 'season');

plt.setp(ax.get_legend().get_texts(), fontsize='15') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='16') # for legend title

ax.set(title = 'Season wise daily distribution of bike rentals',ylabel= 'total_count');

# %%
import seaborn as sns

sns.set(rc={'figure.figsize':(11,8)})

sns.set_context("paper", font_scale=1, rc={"lines.linewidth": 2.5})
#sns.set(style="ticks", context="talk")
#plt.style.use("dark_background")
sns.set_style("dark")

#fig, ax = plt.subplots()
ax = sns.pointplot(data = numeric_bike12[['daytime','cnt','weathersit']], x = 'daytime', y = 'cnt',
              scale = 0.2, hue = 'weathersit');

plt.setp(ax.get_legend().get_texts(), fontsize='15') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='16') # for legend title

ax.set(title = 'Season wise daily distribution of bike rentals',ylabel= 'total_count');

# %%
import seaborn as sns

sns.set(rc={'figure.figsize':(11,8)})

sns.set_context("paper", font_scale=1, rc={"lines.linewidth": 2.5})
#sns.set(style="ticks", context="talk")
#plt.style.use("dark_background")
sns.set_style("dark")

#fig, ax = plt.subplots()
ax = sns.pointplot(data = numeric_bike12[['month','cnt','season']], x = 'month', y = 'cnt',
              scale = 0.2, hue = 'season');

plt.setp(ax.get_legend().get_texts(), fontsize='15') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='16') # for legend title

ax.set(title = 'Season wise daily distribution of bike rentals',ylabel= 'total_count');

# %%
import seaborn as sns

sns.set(rc={'figure.figsize':(11,8)})

sns.set_context("paper", font_scale=1, rc={"lines.linewidth": 2.5})
#sns.set(style="ticks", context="talk")
#plt.style.use("dark_background")
sns.set_style("dark")

#fig, ax = plt.subplots()
ax = sns.pointplot(data = numeric_bike12[['month','registered','weathersit']], x = 'month', y = 'registered',
              scale = 0.2, hue = 'weathersit');

plt.setp(ax.get_legend().get_texts(), fontsize='15') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='16') # for legend title

ax.set(title = 'Season wise daily distribution of bike rentals',ylabel= 'total_count');

# %%
import seaborn as sns

sns.set(rc={'figure.figsize':(11,8)})

sns.set_context("paper", font_scale=1, rc={"lines.linewidth": 2.5})
#sns.set(style="ticks", context="talk")
#plt.style.use("dark_background")
sns.set_style("dark")

#fig, ax = plt.subplots()
ax = sns.pointplot(data = numeric_bike12[['daytime','temp','season']], x = 'daytime', y = 'temp',
              scale = 0.2, hue = 'season');

plt.setp(ax.get_legend().get_texts(), fontsize='15') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='16') # for legend title

ax.set(title = 'Bike rentals',ylabel= 'temp');

# %%
sns.set(rc={'figure.figsize':(11,8)})

sns.set_context("paper", font_scale=1, rc={"lines.linewidth": 2.5})
#sns.set(style="ticks", context="talk")
#plt.style.use("dark_background")
sns.set_style("dark")

#fig, ax = plt.subplots()
ax = sns.pointplot(data = numeric_bike12[['month','temp','season']], x = 'month', y = 'temp',
              scale = 0.2, hue = 'season');

plt.setp(ax.get_legend().get_texts(), fontsize='15') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='16') # for legend title

ax.set(title = 'Bike rentals',ylabel= 'temp');

# %%
sns.set(rc={'figure.figsize':(11,8)})

sns.set_context("paper", font_scale=1, rc={"lines.linewidth": 2.5})
#sns.set(style="ticks", context="talk")
#plt.style.use("dark_background")
sns.set_style("dark")

#fig, ax = plt.subplots()
ax = sns.pointplot(data = numeric_bike12[['month','temp','weathersit']], x = 'month', y = 'temp',
              scale = 0.2, hue = 'weathersit');

plt.setp(ax.get_legend().get_texts(), fontsize='15') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='16') # for legend title

ax.set(title = 'Bike rentals',ylabel= 'temperature');

# %%
sns.set(rc={'figure.figsize':(11,8)})

sns.set_context("paper", font_scale=1, rc={"lines.linewidth": 2.5})
#sns.set(style="ticks", context="talk")
#plt.style.use("dark_background")
sns.set_style("dark")

#fig, ax = plt.subplots()
ax = sns.pointplot(data = numeric_bike12[['month','registered','weathersit']], x = 'month', y = 'registered',
              scale = 0.2, hue = 'weathersit');

plt.setp(ax.get_legend().get_texts(), fontsize='15') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='16') # for legend title

ax.set(title = 'Season wise daily distribution of bike rentals',ylabel= 'total_count');

# %%
import seaborn as sns

sns.set(rc={'figure.figsize':(11,8)})

sns.set_context("paper", font_scale=1, rc={"lines.linewidth": 2.5})
#sns.set(style="ticks", context="talk")
#plt.style.use("dark_background")
sns.set_style("dark")

#fig, ax = plt.subplots()
ax = sns.pointplot(data = bike_day[['month','registered','season']], x = 'month', y = 'registered',
              scale = 0.2, hue = 'season');

plt.setp(ax.get_legend().get_texts(), fontsize='15') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='16') # for legend title

ax.set(title = 'Season wise daily distribution of bike rentals',ylabel= 'total_count');

# %%
sns.set(rc={'figure.figsize':(11,8)})

sns.set_context("paper", font_scale=1, rc={"lines.linewidth": 2.5})
#sns.set(style="ticks", context="talk")
#plt.style.use("dark_background")
sns.set_style("dark")

#fig, ax = plt.subplots()
ax = sns.pointplot(data = bike_day[['month','casual','season']], x = 'month', y = 'casual',
              scale = 0.2, hue = 'season');

plt.setp(ax.get_legend().get_texts(), fontsize='15') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='16') # for legend title

ax.set(title = 'Season wise daily distribution of bike rentals',ylabel= 'total_count');

# %%
bike_day
# Out:
#      instant     daytime  season  year  ...  windspeed casual registered   cnt
# 0          1  2011-01-01  Spring  2011  ...   0.160446    331        654   985
# 1          2  2011-01-02  Spring  2011  ...   0.248539    131        670   801
# 2          3  2011-01-03  Spring  2011  ...   0.248309    120       1229  1349
# 3          4  2011-01-04  Spring  2011  ...   0.160296    108       1454  1562
# 4          5  2011-01-05  Spring  2011  ...   0.186900     82       1518  1600
# ..       ...         ...     ...   ...  ...        ...    ...        ...   ...
# 726      727  2012-12-27  Spring  2012  ...   0.350133    247       1867  2114
# 727      728  2012-12-28  Spring  2012  ...   0.155471    644       2451  3095
# 728      729  2012-12-29  Spring  2012  ...   0.124383    159       1182  1341
# 729      730  2012-12-30  Spring  2012  ...   0.350754    364       1432  1796
# 730      731  2012-12-31  Spring  2012  ...   0.154846    439       2290  2729
#
# [731 rows x 16 columns]

# %%
sns.lineplot(x='weekday', y='registered', data=bike_day )

# %%
poinplot

# %%
sns.set(rc={'figure.figsize':(11,8)})

sns.set_context("paper", font_scale=1, rc={"lines.linewidth": 2.5})
#sns.set(style="ticks", context="talk")
#plt.style.use("dark_background")
sns.set_style("dark")

#fig, ax = plt.subplots()
ax = sns.pointplot(data = bike_day[['weekday','registered','season']], x = 'weekday', y = 'registered',
              scale = 0.2, hue = 'season');

plt.setp(ax.get_legend().get_texts(), fontsize='15') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='16') # for legend title

ax.set(title = 'Season wise daily distribution of bike rentals',ylabel= 'total_count');
